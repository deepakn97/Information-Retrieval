# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import nltk 
from time import time
from collections import Counter
from nltk.corpus import stopwords
from nltk import FreqDist,ngrams,word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package stopwords to /home/deepak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/deepak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/deepak/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/deepak/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# give me tokens, I will give non stop(word) tokens
def remove_stopwords(data):
    stop_words = Counter(stopwords.words('english'))
    ans = []
    for each in data:
        if(each not in stop_words.keys()):
            ans.append(each)
    return ans

# %%
# give me tokens, I will give you lemmatized tokens
def lemmatizer(data):
    lmtzr = WordNetLemmatizer()
    ans = []
    for each in data:
        ans.append(lmtzr.lemmatize(each))
    return ans

# %%
# same as above(replace lemmatize with stemmed)
def stemmer(data):
    ps = PorterStemmer()
    ans = []
    for each in data:
        ans.append(ps.stem(each))
    return ans

# %%
def A1_task1(dataset, sw = 0, st = 0, lem= 0):
    data = pd.read_csv(dataset)
    
    # concatenation
    text = ""
    for i in range(data.shape[0]):
        text += str(data['Text'][i])
    
    tokens = word_tokenize(text)
    if(sw):
        tokens = remove_stopwords(tokens)
    if(lem):
        tokens = lemmatizer(tokens)
    if(st):
        tokens = stemmer(tokens)
        
    fDist = FreqDist(tokens)
    dictionary = dict(zip(fDist.keys(),fDist.values()))
    sorted_dict = sorted(dictionary.items(), key=lambda x: x[1],reverse= True)
   
    x = np.arange(0,400)
    y = [sorted_dict[i][1] for i in range(400)]
    plt.plot(x,y,'r')
    plt.plot(x,y,'b.')
    plt.xlabel("Rank")
    plt.ylabel("Frequency")
    plt.show()                  
     
    print ("TOP 20 Words : ")
    for i in range(20): 
        print (str(i+1)+". "+sorted_dict[i][0]," : ",sorted_dict[i][1])

# %% [markdown]
# # Testing with Dataset1

# %% [markdown]
# ## Analyzing without any preprocessing

# %%
A1_task1('questions-data.csv', 0, 0, 0)
# Out:
# TOP 20 Words :
# 1. the  :  205961
# 2. ,  :  162423
# 3. to  :  149171
# 4. a  :  118288
# 5. i  :  111537
# 6. .  :  94667
# 7. is  :  88799
# 8. ?  :  84690
# 9. and  :  83215
# 10. )  :  69432
# 11. of  :  68121
# 12. (  :  67465
# 13. that  :  61290
# 14. :  :  60627
# 15. it  :  57113
# 16. in  :  56031
# 17. for  :  44410
# 18. this  :  43486
# 19. be  :  37528
# 20. on  :  36206

# %% [markdown]
# ## Analyzing after removing stopwords

# %%
A1_task1('questions-data.csv', 1, 0, 0)
# Out:
# TOP 20 Words :
# 1. ,  :  162423
# 2. .  :  94667
# 3. ?  :  84690
# 4. )  :  69432
# 5. (  :  67465
# 6. :  :  60627
# 7. ''  :  31853
# 8. ``  :  22716
# 9. ;  :  21738
# 10. 's  :  20101
# 11. n't  :  18932
# 12. would  :  18377
# 13. server  :  16088
# 14. key  :  16067
# 15. password  :  15711
# 16. using  :  15390
# 17. %  :  15070
# 18. use  :  15006
# 19. security  :  14566
# 20. [  :  14524

# %% [markdown]
# ## Analyzing after Lemmatization

# %%
A1_task1('questions-data.csv', 0, 1, 0)
# Out:
# TOP 20 Words :
# 1. the  :  205961
# 2. ,  :  162423
# 3. to  :  149194
# 4. a  :  118288
# 5. i  :  111539
# 6. .  :  94667
# 7. is  :  88799
# 8. ?  :  84690
# 9. and  :  83216
# 10. )  :  69432
# 11. of  :  68121
# 12. (  :  67465
# 13. that  :  61343
# 14. :  :  60627
# 15. it  :  60530
# 16. in  :  56039
# 17. for  :  44410
# 18. thi  :  43487
# 19. be  :  41763
# 20. use  :  40794

# %% [markdown]
# ## Analyzing after Stemming

# %%
A1_task1('questions-data.csv', 0, 0, 1)
# Out:
# TOP 20 Words :
# 1. the  :  205961
# 2. ,  :  162423
# 3. to  :  149171
# 4. a  :  142002
# 5. i  :  111543
# 6. .  :  94667
# 7. is  :  88799
# 8. ?  :  84690
# 9. and  :  83215
# 10. )  :  69432
# 11. of  :  68121
# 12. (  :  67465
# 13. that  :  61290
# 14. :  :  60627
# 15. it  :  60530
# 16. in  :  56039
# 17. for  :  44410
# 18. this  :  43486
# 19. be  :  37536
# 20. on  :  36206

# %% [markdown]
# ## Analyzing after removing stopwords, lemmatization and stemming

# %%
A1_task1('questions-data.csv', 1, 1, 1)
# Out:
# TOP 20 Words :
# 1. ,  :  162423
# 2. .  :  94667
# 3. ?  :  84690
# 4. )  :  69432
# 5. (  :  67465
# 6. :  :  60627
# 7. use  :  38605
# 8. ''  :  31853
# 9. secur  :  24437
# 10. ``  :  22716
# 11. ;  :  21738
# 12. password  :  20289
# 13. 's  :  20101
# 14. key  :  19527
# 15. n't  :  18932
# 16. would  :  18377
# 17. server  :  18312
# 18. user  :  18273
# 19. %  :  15070
# 20. encrypt  :  14772

# %% [markdown]
# # Testing with Dataset2

# %% [markdown]
# ## Analyzing without any preprocessing

# %%
A1_task1('sem_scho.csv', 0, 0, 0)
# Out:
# TOP 20 Words :
# 1. the  :  21813
# 2. of  :  21169
# 3. .  :  16893
# 4. and  :  12175
# 5. in  :  10125
# 6. a  :  9606
# 7. to  :  9267
# 8. (  :  7925
# 9. )  :  7527
# 10. is  :  6208
# 11. ,  :  5194
# 12. for  :  5036
# 13. with  :  3928
# 14. that  :  3638
# 15. The  :  3515
# 16. are  :  3017
# 17. on  :  2920
# 18. by  :  2628
# 19. this  :  2386
# 20. an  :  2318

# %% [markdown]
# ## Analyzing after removing stopwords

# %%
A1_task1('sem_scho.csv', 1, 0, 0)
# Out:
# TOP 20 Words :
# 1. .  :  16893
# 2. (  :  7925
# 3. )  :  7527
# 4. ,  :  5194
# 5. The  :  3515
# 6. We  :  1408
# 7. In  :  1364
# 8. study  :  1356
# 9. paper  :  1300
# 10. This  :  1214
# 11. data  :  924
# 12. patients  :  879
# 13. :  :  850
# 14. used  :  836
# 15. system  :  783
# 16. A  :  775
# 17. using  :  774
# 18. 's  :  755
# 19. model  :  734
# 20. two  :  687

# %% [markdown]
# ## Analyzing after Lemmatization

# %%
A1_task1('sem_scho.csv', 0, 1, 0)
# Out:
# TOP 20 Words :
# 1. the  :  25334
# 2. of  :  21169
# 3. .  :  16893
# 4. and  :  12318
# 5. in  :  10128
# 6. a  :  9606
# 7. to  :  9268
# 8. (  :  7925
# 9. )  :  7527
# 10. is  :  6208
# 11. for  :  5243
# 12. ,  :  5194
# 13. with  :  3990
# 14. that  :  3649
# 15. thi  :  3600
# 16. are  :  3019
# 17. on  :  2922
# 18. by  :  2628
# 19. use  :  2518
# 20. an  :  2322

# %% [markdown]
# ## Analyzing after Stemming

# %%
A1_task1('sem_scho.csv', 0, 0, 1)
# Out:
# TOP 20 Words :
# 1. the  :  21813
# 2. of  :  21169
# 3. .  :  16893
# 4. and  :  12175
# 5. a  :  11684
# 6. in  :  10126
# 7. to  :  9267
# 8. (  :  7925
# 9. )  :  7527
# 10. is  :  6208
# 11. ,  :  5194
# 12. for  :  5036
# 13. with  :  3928
# 14. that  :  3638
# 15. The  :  3515
# 16. are  :  3017
# 17. on  :  2920
# 18. by  :  2628
# 19. this  :  2386
# 20. an  :  2320

# %% [markdown]
# ## Analyzing after removing stopwords, lemmatization and stemming

# %%
A1_task1('sem_scho.csv', 1, 1, 1)
# Out:
# TOP 20 Words :
# 1. .  :  16893
# 2. (  :  7925
# 3. )  :  7527
# 4. ,  :  5194
# 5. the  :  3521
# 6. use  :  2415
# 7. studi  :  2073
# 8. system  :  1453
# 9. We  :  1408
# 10. In  :  1364
# 11. paper  :  1355
# 12. model  :  1286
# 13. method  :  1268
# 14. present  :  1259
# 15. thi  :  1214
# 16. patient  :  1076
# 17. data  :  993
# 18. effect  :  949
# 19. develop  :  940
# 20. result  :  930

# %% [markdown]
# ## Observations :
# 1. Stop words removal has the most significant effect (considering only the top-20 occuring terms).
# 2. Stop words coupled with lemmatization and stemming results in inclusion of more meaningful root words in the higher ranks.

# %% [markdown]
# # Task 2

# %%
def A1_task2(dataset):
    data = pd.read_csv(dataset)
    dictionary = set()
    num_tokens = 0 
    T = [] # List of chapterwise number of tokens
    M = [] # List of chapterwise number of unique words
    for i in range(data.shape[0]):
        text = str(data['Text'][i])
        tokens = word_tokenize(text)
        for t in tokens:
            dictionary.add(t) 
        num_tokens += len(tokens)
        T.append(num_tokens)
        M.append(len(dictionary))
    return T,M

# %% [markdown]
# ## Testing on dataset 1

# %%
Terms,Dictionary = A1_task2('questions-data.csv')

# %%
x = np.arange(0,len(Terms))
plt.plot(Terms,Dictionary,'r', )
plt.xlabel("Number of Tokens")
plt.ylabel("Number of Unique Terms")
plt.title("Dataset 1")
plt.show()

# %% [markdown]
# ## Testing on dataset 2

# %%
Terms,Dictionary = A1_task2('sem_scho.csv')

# %%
x = np.arange(0,len(Terms))
plt.plot(Terms,Dictionary,'r', )
plt.xlabel("Number of Tokens")
plt.ylabel("Number of Unique Terms")
plt.title("Dataset 2")
plt.show()

# %% [markdown]
# ## Observations
# 1. As we can see from the graph, the trend is not linear. It looks like it is following the **Heap's law**.
# 2. Ideally the curve should flatten out as the dataset size increases(tokens increases and unique word remains almost same), but due to human errors and ever evolving content, unique terms keep adding on.
